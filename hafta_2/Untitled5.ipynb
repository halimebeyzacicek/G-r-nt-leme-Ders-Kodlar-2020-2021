# %%
import os
import numpy as np 
import matplotlib.pyplot as plt

# %%
def compare_list_ndarray():
    list_1=[1,"dkdjlfj,3",'4',5,6]
    list_2=[2,"dkafjkdf,3",'1114',15,26]
    
    print(list_1+list_2)

    list_1=[1,2,3,4]
    list_2=[1,2,3,4]
    list_1+list_2+[10]
    print(list_1+list_2+[10])
    
    list_3=np.asarray([1,2,3,4,5,6])
    list_4=np.asarray([1,2,3,4,5,6])
    print(list_3+list_4+10)
def get_jpeg_files():
    os.getcwd()
    os.listdir()
    path=os.getcwd()
    path=os.getcwd()
    jpg_files=[f for f in os.listdir(path) if f.endswith('.jpg')]
    return jpg_files
get_jpeg_files()
compare_list_ndarray()
get_jpeg_files
# Out:
# [1, 'dkdjlfj,3', '4', 5, 6, 2, 'dkafjkdf,3', '1114', 15, 26]
# [1, 2, 3, 4, 1, 2, 3, 4, 10]
# [12 14 16 18 20 22]
# <function __main__.get_jpeg_files()>

# %%
def display_two_image(im_1,im_2):
    plt.subplot(1,2,1)
    plt.imshow(image_1)

    plt.subplot(1,2,2)
    plt.imshow(image_2) #+30

    plt.show
def rotate(im_1):
    m,n,k=im_1.shape
    new_image=np.zeros((n,m,k),dtype='uint8')
    
    for i in range (m):
        for j in range (n):
            temp=image_1[i,j]
            new_image[j,i]=temp
    return new_image

# %%
image_1=plt.imread('pic_2.jpg')
image_2=rotate(image_1)
display_two_image(image_1,image_2)

# %%
image_1
# Out:
# array([[[222, 255, 208],
#         [220, 253, 210],
#         [207, 239, 202],
#         ...,
#         [ 98, 110, 110],
#         [ 87,  99,  99],
#         [ 77,  89,  89]],
#
#        [[212, 249, 198],
#         [212, 248, 202],
#         [202, 237, 197],
#         ...,
#         [ 75,  87,  87],
#         [ 68,  80,  80],
#         [ 60,  72,  72]],
#
#        [[190, 227, 173],
#         [196, 233, 182],
#         [194, 230, 186],
#         ...,
#         [ 62,  74,  74],
#         [ 59,  71,  71],
#         [ 57,  69,  69]],
#
#        ...,
#
#        [[170, 176, 132],
#         [175, 181, 137],
#         [173, 179, 135],
#         ...,
#         [209, 205, 202],
#         [209, 205, 202],
#         [207, 203, 202]],
#
#        [[185, 191, 147],
#         [177, 183, 139],
#         [176, 182, 136],
#         ...,
#         [232, 227, 224],
#         [230, 225, 222],
#         [226, 221, 218]],
#
#        [[193, 199, 153],
#         [186, 192, 146],
#         [185, 191, 143],
#         ...,
#         [230, 222, 220],
#         [227, 219, 217],
#         [224, 216, 214]]], dtype=uint8)

# %%
image_2
# Out:
# array([[[222, 255, 208],
#         [212, 249, 198],
#         [190, 227, 173],
#         ...,
#         [170, 176, 132],
#         [185, 191, 147],
#         [193, 199, 153]],
#
#        [[220, 253, 210],
#         [212, 248, 202],
#         [196, 233, 182],
#         ...,
#         [175, 181, 137],
#         [177, 183, 139],
#         [186, 192, 146]],
#
#        [[207, 239, 202],
#         [202, 237, 197],
#         [194, 230, 186],
#         ...,
#         [173, 179, 135],
#         [176, 182, 136],
#         [185, 191, 143]],
#
#        ...,
#
#        [[ 98, 110, 110],
#         [ 75,  87,  87],
#         [ 62,  74,  74],
#         ...,
#         [209, 205, 202],
#         [232, 227, 224],
#         [230, 222, 220]],
#
#        [[ 87,  99,  99],
#         [ 68,  80,  80],
#         [ 59,  71,  71],
#         ...,
#         [209, 205, 202],
#         [230, 225, 222],
#         [227, 219, 217]],
#
#        [[ 77,  89,  89],
#         [ 60,  72,  72],
#         [ 57,  69,  69],
#         ...,
#         [207, 203, 202],
#         [226, 221, 218],
#         [224, 216, 214]]], dtype=uint8)
